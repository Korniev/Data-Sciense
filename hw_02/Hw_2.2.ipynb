# %% [markdown]
#                                         Домашнє Завдання N 2

# %% [markdown]
#                                     Частина друга: Аналіз файлів

# %%
# imports
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.__version__, np.__version__
# Out:
# ('2.1.4', '1.26.3')

# %%
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

survey = pd.read_csv("2017_jun_final.csv")

survey
# Out:
#          N                    Посада Мова програмування Спеціалізація  \
# 0        1        Junior QA engineer                NaN     Manual QA
# 1        2        Junior QA engineer                NaN     Manual QA
# 2        3         Software Engineer            C#/.NET           NaN
# 3        4         Software Engineer         JavaScript           NaN
# 4        5  Senior Software Engineer         JavaScript           NaN
# ...    ...                       ...                ...           ...
# 8699  8700               QA engineer                NaN     Manual QA
# 8700  8701                 Marketing                NaN           NaN
# 8701  8702  Junior Software Engineer         Ruby/Rails           NaN
# 8702  8703                 Team lead                NaN           NaN
# 8703  8704  Senior Software Engineer               Java           NaN
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# ...

# %%
# Прочитайте отриману таблицю, використовуючи метод head

survey.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %%
# Визначте розмір таблиці за допомогою методу shape

survey.shape

print(f"rows - {survey.shape[0]}, columns - {survey.shape[1]}")
# Out:
# rows - 8704, columns - 25

# %%
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

survey.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

missing_rate = survey.isnull().sum() / len(survey)

missing_rate
# Out:
# N                                   0.000000
# Посада                              0.000000
# Мова програмування                  0.442325
# Спеціалізація                       0.829389
# Загальний досвід роботи             0.000000
# Досвід роботи на поточному місці    0.000000
# Зарплата на місяць                  0.000000
# Зміна зарплати за 12 місяців        0.000000
# Місто                               0.000000
# Розмір компанії                     0.000000
# Тип компанії                        0.000000
# Стать                               0.000000
# Вік                                 0.000000
# Освіта                              0.000000
# Університет                         0.041131
# Ще студент                          0.000000
# Рівень англійської                  0.000000
# Предметна область                   0.025620
# Дата заповнення                     0.000000
# User.Agent                          0.000000
# exp                                 0.000000
# ...

# %%
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

columns_with_missing_values = survey.columns[survey.isnull().any()].tolist()
columns_with_missing_values.remove("Мова програмування")

cleaned_survey = survey.drop(columns_with_missing_values, axis=1)

cleaned_survey
# Out:
#          N                    Посада Мова програмування  \
# 0        1        Junior QA engineer                NaN
# 1        2        Junior QA engineer                NaN
# 2        3         Software Engineer            C#/.NET
# 3        4         Software Engineer         JavaScript
# 4        5  Senior Software Engineer         JavaScript
# ...    ...                       ...                ...
# 8699  8700               QA engineer                NaN
# 8700  8701                 Marketing                NaN
# 8701  8702  Junior Software Engineer         Ruby/Rails
# 8702  8703                 Team lead                NaN
# 8703  8704  Senior Software Engineer               Java
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# 1            менше 3 місяців                  менше 3 місяців
# 2                          4                                1
# ...

# %%
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

missing_rate = cleaned_survey.isnull().sum() / len(survey)

missing_rate
# Out:
# N                                   0.000000
# Посада                              0.000000
# Мова програмування                  0.442325
# Загальний досвід роботи             0.000000
# Досвід роботи на поточному місці    0.000000
# Зарплата на місяць                  0.000000
# Зміна зарплати за 12 місяців        0.000000
# Місто                               0.000000
# Розмір компанії                     0.000000
# Тип компанії                        0.000000
# Стать                               0.000000
# Вік                                 0.000000
# Освіта                              0.000000
# Ще студент                          0.000000
# Рівень англійської                  0.000000
# Дата заповнення                     0.000000
# User.Agent                          0.000000
# exp                                 0.000000
# current_job_exp                     0.000000
# salary                              0.000000
# dtype: float64

# %%
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

dropped_nan_survey = cleaned_survey.dropna(how='any')

dropped_nan_survey
# Out:
#          N                    Посада Мова програмування  \
# 2        3         Software Engineer            C#/.NET
# 3        4         Software Engineer         JavaScript
# 4        5  Senior Software Engineer         JavaScript
# 6        7  Junior Software Engineer            C#/.NET
# 7        8  Senior Software Engineer                C++
# ...    ...                       ...                ...
# 8692  8693         Software Engineer               Java
# 8694  8695  Junior Software Engineer            C#/.NET
# 8695  8696         Software Engineer             Python
# 8701  8702  Junior Software Engineer         Ruby/Rails
# 8703  8704  Senior Software Engineer               Java
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 2                          4                                1
# 3                          5                                4
# 4          10 і більше років                              0.5
# ...

# %%
# Визначте новий розмір таблиці за допомогою методу shape

dropped_nan_survey.shape

print(f"rows - {dropped_nan_survey.shape[0]}, columns - {dropped_nan_survey.shape[1]}")
# Out:
# rows - 4854, columns - 20

# %%
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

python_data = dropped_nan_survey[dropped_nan_survey['Мова програмування'] == 'Python']

python_data
# Out:
#          N                    Посада Мова програмування  \
# 12      13         Software Engineer             Python
# 68      69         Software Engineer             Python
# 87      88  Junior Software Engineer             Python
# 114    115  Junior Software Engineer             Python
# 143    144  Junior Software Engineer             Python
# ...    ...                       ...                ...
# 8546  8547         Software Engineer             Python
# 8625  8626         Software Engineer             Python
# 8635  8636  Senior Software Engineer             Python
# 8673  8674  Junior Software Engineer             Python
# 8695  8696         Software Engineer             Python
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# 68                       1.5                              0.5
# 87                       0.5                              0.5
# ...

# %%
# Визначте розмір таблиці python_data за допомогою методу shape

python_data.shape

print(f"rows - {python_data.shape[0]}, columns - {python_data.shape[1]}")
# Out:
# rows - 207, columns - 20

# %%
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

grouped_by_position = python_data.groupby(by='Посада')

grouped_by_position

# %%
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата на місяць"

aggregated_salary = grouped_by_position['Зарплата на місяць'].agg(['min', 'max'])

aggregated_salary
# Out:
#                            min   max
# Посада
# Junior Software Engineer   100  1250
# Senior Software Engineer  1300  9200
# Software Engineer          500  5400
# System Architect          3000  5000
# Technical Lead            1425  6200

# %%
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

def fill_avg_salary(python_data):
    return python_data['Зарплата на місяць'].mean().round(2)

aggregated_salary['avg'] = grouped_by_position.apply(fill_avg_salary)

aggregated_salary
# Out:
#                            min   max      avg
# Посада
# Junior Software Engineer   100  1250   560.84
# Senior Software Engineer  1300  9200  3387.10
# Software Engineer          500  5400  1799.07
# System Architect          3000  5000  4000.00
# Technical Lead            1425  6200  3165.91

# %%
# Створіть описову статистику за допомогою методу describe для нового стовпчика.

aggregated_salary['avg'].describe().round(2)
# Out:
# count       5.00
# mean     2582.58
# std      1387.26
# min       560.84
# 25%      1799.07
# 50%      3165.91
# 75%      3387.10
# max      4000.00
# Name: avg, dtype: float64

# %%
# Збережіть отриману таблицю в CSV файл

aggregated_salary.to_csv('aggregated_salary.csv', index=False)

# %%
# Гістограма розподілу зарплат

plt.figure(figsize=(10, 6))
sns.histplot(python_data['Зарплата на місяць'], color='blue', kde=True)
plt.title('Розподіл зарплат серед спеціалістів, які вказали Python')
plt.xlabel('Зарплата на місяць')
plt.ylabel('Кількість спеціалістів')
plt.grid(True)

plt.show()

# %%
# Boxplot зарплат за посадами

plt.figure(figsize=(12, 8))
sns.boxplot(x='Посада', y='Зарплата на місяць', data=python_data, palette='rainbow')
plt.xticks(rotation=45)
plt.title('Розподіл зарплат за посадами')
plt.xlabel('Посада')
plt.ylabel('Зарплата на місяць')

plt.show()

# %%
# Кругова діаграма розподілу мов програмування

languages_data = survey['Мова програмування'].value_counts().reset_index()
languages_data.columns = ['Мова', 'Кількість']

plt.figure(figsize=(10, 10))
plt.pie(languages_data['Кількість'], startangle=140, colors=sns.color_palette('bright'))
plt.title('Розподіл мов програмування серед спеціалістів')
plt.legend(languages_data['Мова'], title="Мови програмування", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.show()

# %%
# Графік розсіювання в залежності зарплати від стажу роботи

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Загальний досвід роботи', y='Зарплата на місяць', data=python_data, hue='Посада', style='Посада', palette='coolwarm')
plt.title('Залежність зарплати від досвіду роботи')
plt.xlabel('Загальний досвід роботи (роки)')
plt.ylabel('Зарплата на місяць')
plt.legend(title='Посада')
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
# Графік зміни середньої зарплати за посадами

plt.figure(figsize=(12, 8))
sns.barplot(x='Посада', y='avg', data=aggregated_salary.reset_index(), palette='Set2')
plt.xticks(rotation=45)
plt.title('Середня зарплата за посадами')
plt.xlabel('Посада')
plt.ylabel('Середня зарплата на місяць')

plt.show()
